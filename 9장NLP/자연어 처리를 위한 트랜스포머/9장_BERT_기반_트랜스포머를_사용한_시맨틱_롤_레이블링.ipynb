# %% [markdown]
# <a href="https://colab.research.google.com/github/namwootree/Basic_Skill/blob/main/9%EC%9E%A5NLP/%EC%9E%90%EC%97%B0%EC%96%B4%20%EC%B2%98%EB%A6%AC%EB%A5%BC%20%EC%9C%84%ED%95%9C%20%ED%8A%B8%EB%9E%9C%EC%8A%A4%ED%8F%AC%EB%A8%B8/9%EC%9E%A5_BERT_%EA%B8%B0%EB%B0%98_%ED%8A%B8%EB%9E%9C%EC%8A%A4%ED%8F%AC%EB%A8%B8%EB%A5%BC_%EC%82%AC%EC%9A%A9%ED%95%9C_%EC%8B%9C%EB%A7%A8%ED%8B%B1_%EB%A1%A4_%EB%A0%88%EC%9D%B4%EB%B8%94%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SRL
# 문장에서 단어 또는 단어 그룹이 담당하는 시맨틱 역할과 술어에 의해 설정된 관계에 레이블을 지정한다
#
# ### 시맨틱 역할
# 문장에서 주 동사와 관련하여 명사 또는 명사구가 담당하는 역할이다
#
# ### 술어
# 주어 또는 에이전트를 묘사한다. 주어의 특징이나 동작에 관한 정보를 제공하는 모든 것이 될 수 있다

# %%
# !pip install allennlp allennlp-models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 729 kB 12.7 MB/s
# ...
#      |████████████████████████████████| 464 kB 67.4 MB/s
# ...
#      |████████████████████████████████| 229 kB 75.2 MB/s
# ...
#      |████████████████████████████████| 248 kB 69.6 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 880 kB 62.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 60.3 MB/s
# ...
#      |████████████████████████████████| 125 kB 68.5 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 64.1 MB/s
# ...
#      |████████████████████████████████| 297 kB 74.8 MB/s
# ...
#      |████████████████████████████████| 21.0 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 53.7 MB/s
# ...
#      |████████████████████████████████| 592 kB 65.2 MB/s
# ...

# %%
# !echo '{"sentence": "Did Bob really think he could prepare a meal for 50 people in only a few hours?"}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-07-17 06:25:26,760 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-07-17 06:25:26,922 - INFO - cached_path - https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz not found in cache, downloading to /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# ...
#                                                                             MB
# 2022-07-17 06:25:35,174 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# ...

# %%
# !echo '{"sentence": "Mrs. and Mr. Tomaso went to Europe for vacation and visited Paris and first went to visit the Eiffel Tower."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-07-17 06:28:39,359 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-07-17 06:28:39,508 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2022-07-17 06:28:39,508 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2022-07-17 06:28:39,508 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /tmp/tmp2mz00qpn
# 2022-07-17 06:28:43,331 - INFO - allennlp.common.params - dataset_reader.type = srl
# ...

# %%
# !echo '{"sentence": "John wanted to drink tea, Mary likes to drink coffee but Karim drank some cool water and Faiza would like to drink tomato juice."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-07-17 06:30:12,037 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-07-17 06:30:12,184 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2022-07-17 06:30:12,184 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2022-07-17 06:30:12,185 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /tmp/tmp5m__v0k5
# 2022-07-17 06:30:15,973 - INFO - allennlp.common.params - dataset_reader.type = srl
# ...

# %%
# !echo '{"sentence": "Alice, whose husband went jogging every Sunday, liked to go to a dancing class in the meantime."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-07-17 06:31:52,425 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-07-17 06:31:52,574 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2022-07-17 06:31:52,574 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2022-07-17 06:31:52,574 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /tmp/tmpxk6oljpr
# 2022-07-17 06:31:56,542 - INFO - allennlp.common.params - dataset_reader.type = srl
# ...

# %%
# !echo '{"sentence": "The bright sun, the blue sky, the warm sand, the palm trees, everything round off."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-07-17 06:33:16,405 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-07-17 06:33:16,543 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2022-07-17 06:33:16,543 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2022-07-17 06:33:16,543 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /tmp/tmpj3md370v
# 2022-07-17 06:33:20,367 - INFO - allennlp.common.params - dataset_reader.type = srl
# ...

# %%
# !echo '{"sentence": "The bright sun, the blue sky, the warm sand, the palm trees, everything rounds off."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-07-17 06:34:32,438 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-07-17 06:34:32,583 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2022-07-17 06:34:32,583 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2022-07-17 06:34:32,583 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /tmp/tmpu3nyqnve
# 2022-07-17 06:34:36,434 - INFO - allennlp.common.params - dataset_reader.type = srl
# ...

# %%
# !echo '{"sentence": "Now, ice pucks guys!"}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-07-17 06:36:23,342 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-07-17 06:36:23,491 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2022-07-17 06:36:23,491 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2022-07-17 06:36:23,491 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /tmp/tmpeahqt2gj
# 2022-07-17 06:36:27,293 - INFO - allennlp.common.params - dataset_reader.type = srl
# ...
