# %% [markdown]
# <a href="https://colab.research.google.com/github/namwootree/Basic_Skill/blob/main/NLP/%EC%9E%90%EC%97%B0%EC%96%B4%20%EC%B2%98%EB%A6%AC%EB%A5%BC%20%EC%9C%84%ED%95%9C%20%ED%8A%B8%EB%9E%9C%EC%8A%A4%ED%8F%AC%EB%A8%B8/10%EC%9E%A5_%EB%8D%B0%EC%9D%B4%ED%84%B0%EA%B0%80_%EB%A7%90%ED%95%98%EA%B2%8C_%ED%95%98%EB%9D%BC_%EC%9D%B4%EC%95%BC%EA%B8%B0%2C_%EC%A7%88%EB%AC%B8%2C_%EB%8B%B5%EB%B3%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 4.4 MB 4.9 MB/s
#      |████████████████████████████████| 101 kB 8.1 MB/s
#      |████████████████████████████████| 596 kB 63.3 MB/s
#      |████████████████████████████████| 6.6 MB 43.8 MB/s

# %%
from transformers import pipeline

# %%
nlp_qa = pipeline('question-answering')
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
# Downloading:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/249M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %%
sequence = "The traffic began to slow down on Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show."

nlp_qa(context=sequence, question='Where is Pioneer Boulevard ?')
# Out:
# {'answer': 'Los Angeles', 'end': 66, 'score': 0.9879735112190247, 'start': 55}

# %%
nlp_ner = pipeline("ner")

print(nlp_ner(sequence))
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english)
# Downloading:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.24G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# ...

# %%
print("Question 1.",nlp_qa(context=sequence, question='Where is Pioneer Boulevard ?'))
print("Question 2.",nlp_qa(context=sequence, question='Where is Los Angeles located?'))
print("Question 3.",nlp_qa(context=sequence, question='Where is LA ?'))
print("Question 4.",nlp_qa(context=sequence, question='Where is Barstow ?'))
print("Question 5.",nlp_qa(context=sequence, question='Where is Las Vegas located ?'))
# Out:
# Question 1. {'score': 0.9879735112190247, 'start': 55, 'end': 66, 'answer': 'Los Angeles'}
# Question 2. {'score': 0.9875389337539673, 'start': 34, 'end': 51, 'answer': 'Pioneer Boulevard'}
# Question 3. {'score': 0.5090532898902893, 'start': 55, 'end': 66, 'answer': 'Los Angeles'}
# Question 4. {'score': 0.3695444166660309, 'start': 387, 'end': 396, 'answer': 'Las Vegas'}
# Question 5. {'score': 0.21839873492717743, 'start': 355, 'end': 362, 'answer': 'Barstow'}

# %%
nlp_qa = pipeline('question-answering')
nlp_qa(context=sequence, question='Who was singing ?')
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
# {'answer': 'Nat King Cole',
#  'end': 277,
#  'score': 0.9653673768043518,
#  'start': 264}

# %%
nlp_qa(context=sequence, question='Who was going to Las Vegas ?')
# Out:
# {'answer': 'Nat King Cole',
#  'end': 277,
#  'score': 0.43162474036216736,
#  'start': 264}

# %%
# !pip install allennlp allennlp-models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 729 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 464 kB 39.4 MB/s
# ...
#      |████████████████████████████████| 125 kB 56.6 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 297 kB 55.9 MB/s
# ...
#      |████████████████████████████████| 880 kB 45.1 MB/s
# ...
#      |████████████████████████████████| 248 kB 40.6 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 750.6 MB 10 kB/s
# ...
#      |████████████████████████████████| 298 kB 49.2 MB/s
# ...
#      |████████████████████████████████| 229 kB 48.8 MB/s
# ...
#      |████████████████████████████████| 106 kB 48.9 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 55.4 MB/s
# ...

# %%
# !echo '{"sentence": "Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-07-17 07:18:31,935 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-07-17 07:18:31,995 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2022-07-17 07:18:31,996 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2022-07-17 07:18:31,996 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /tmp/tmp6dsa2pis
# 2022-07-17 07:18:36,441 - INFO - allennlp.common.params - dataset_reader.type = srl
# ...

# %%
nlp_qa(context=sequence, question='Who are they?')
# Out:
# {'answer': 'Jo and Maria',
#  'end': 305,
#  'score': 0.8486902713775635,
#  'start': 293}

# %%
nlp_qa(context=sequence, question='Who drove to Las Vegas?')
# Out:
# {'answer': 'Nat King Cole was singing as Jo and Maria',
#  'end': 305,
#  'score': 0.3594152629375458,
#  'start': 264}

# %%
print(nlp_qa.model)
# Out:
# DistilBertForQuestionAnswering(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
# ...

# %%
nlp_qa = pipeline('question-answering', model='google/electra-small-generator', tokenizer='google/electra-small-generator')
nlp_qa(context=sequence, question='Who drove to Las Vegas ?')
# Out:
# Downloading:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/51.7M [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/electra-small-generator were not used when initializing ElectraForQuestionAnswering: ['generator_lm_head.weight', 'generator_predictions.dense.bias', 'generator_predictions.LayerNorm.bias', 'generator_lm_head.bias', 'generator_predictions.dense.weight', 'generator_predictions.LayerNorm.weight']
# - This IS expected if you are initializing ElectraForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# !echo '{"sentence": "The traffic began to slow down on Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-07-17 07:33:17,220 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-07-17 07:33:17,283 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2022-07-17 07:33:17,283 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2022-07-17 07:33:17,283 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /tmp/tmpm8t07se6
# 2022-07-17 07:33:22,581 - INFO - allennlp.common.params - dataset_reader.type = srl
# ...

# %%
nlp_qa = pipeline('question-answering')
nlp_qa(context=sequence, question='What was slow?')
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
# {'answer': 'The traffic', 'end': 11, 'score': 0.46530550718307495, 'start': 0}

# %%
nlp_qa = pipeline('question-answering')
nlp_qa(context=sequence, question='What was playing')
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
# {'answer': 'cool jazz', 'end': 152, 'score': 0.351193904876709, 'start': 143}

# %%
nlp_qa = pipeline('question-answering')
nlp_qa(context=sequence, question='Who sees a show?')
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
# {'answer': 'Nat King Cole',
#  'end': 277,
#  'score': 0.5588226914405823,
#  'start': 264}

# %%
# !pip install farm-haystack
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 596 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 219 kB 51.1 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 5.9 MB/s
# ...
#      |████████████████████████████████| 50 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 39.0 MB/s
# ...
#      |████████████████████████████████| 85 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 981 kB 31.7 MB/s
# ...
#      |████████████████████████████████| 322 kB 52.9 MB/s
# ...
#      |████████████████████████████████| 17.9 MB 27.3 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 178 kB 51.6 MB/s
# ...
#      |████████████████████████████████| 381 kB 49.8 MB/s
# ...
#      |████████████████████████████████| 86 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 10.7 MB 44.9 MB/s
# ...
#      |████████████████████████████████| 85 kB 4.0 MB/s
# ...

# %%
# !pip install urllib3
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from haystack.reader.farm import FARMReader
from haystack import Document

# %%
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=True, no_ans_boost=0, return_no_answer=False)

text = "The traffic began to slow down on Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show."
doc = Document(text)
# Out:
# INFO - haystack.modeling.utils -  Using devices: CPU
# INFO - haystack.modeling.utils -  Number of GPUs: 0
# INFO - haystack.modeling.model.language_model -  LOADING MODEL
# INFO - haystack.modeling.model.language_model -  =============
# INFO - haystack.modeling.model.language_model -  Could not find deepset/roberta-base-squad2 locally.
# INFO - haystack.modeling.model.language_model -  Looking on Transformers Model Hub (in local cache and online)...
# INFO - haystack.modeling.model.language_model -  Loaded deepset/roberta-base-squad2
# INFO - haystack.modeling.utils -  Using devices: CPU
# INFO - haystack.modeling.utils -  Number of GPUs: 0
# INFO - haystack.modeling.infer -  Got ya 2 parallel workers to do inference ...
# INFO - haystack.modeling.infer -   0     0
# INFO - haystack.modeling.infer -  /w\   /w\
# INFO - haystack.modeling.infer -  /'\   / \

# %%
reader.predict(query="Where is Pioneer Boulevard located?", documents=[doc])
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.29s/ Batches]
# {'answers': [<Answer {'answer': 'Los Angeles', 'type': 'extractive', 'score': 0.9839139878749847, 'context': 'The traffic began to slow down on Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool ja', 'offsets_in_document': [{'start': 55, 'end': 66}], 'offsets_in_context': [{'start': 55, 'end': 66}], 'document_id': '60d013212c53db602c9ffc9c2b879225', 'meta': {}}>],
#  'no_ans_gap': 10.056201934814453,
#  'query': 'Where is Pioneer Boulevard located?'}

# %%
reader.predict(query="Who drove to Las Vegas?", documents=[doc])
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.05s/ Batches]
# {'answers': [<Answer {'answer': 'Jo and Maria', 'type': 'extractive', 'score': 0.8650399148464203, 'context': 't of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow. They plann', 'offsets_in_document': [{'start': 293, 'end': 305}], 'offsets_in_context': [{'start': 69, 'end': 81}], 'document_id': '60d013212c53db602c9ffc9c2b879225', 'meta': {}}>],
#  'no_ans_gap': 3.783226490020752,
#  'query': 'Who drove to Las Vegas?'}

# %%
reader.predict(query="Who is singing?", documents=[doc])
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.13s/ Batches]
# {'answers': [<Answer {'answer': 'Nat King Cole', 'type': 'extractive', 'score': 0.9958206415176392, 'context': 'r pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and dro', 'offsets_in_document': [{'start': 264, 'end': 277}], 'offsets_in_context': [{'start': 69, 'end': 82}], 'document_id': '60d013212c53db602c9ffc9c2b879225', 'meta': {}}>],
#  'no_ans_gap': 12.141620397567749,
#  'query': 'Who is singing?'}

# %%
reader.predict(query="What is the plan for the night?", documents=[doc])
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.05s/ Batches]
# {'answers': [<Answer {'answer': 'They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show', 'type': 'extractive', 'score': 0.3058335483074188, 'context': 'de their way out of LA and drove toward Barstow. They planned to get to Las Vegas early enough in the evening to have a nice dinner and go see a show.', 'offsets_in_document': [{'start': 364, 'end': 464}], 'offsets_in_context': [{'start': 49, 'end': 149}], 'document_id': '60d013212c53db602c9ffc9c2b879225', 'meta': {}}>],
#  'no_ans_gap': 6.077341198921204,
#  'query': 'What is the plan for the night?'}

# %%
questions = ["Where is Los Angeles located?",
             "Where is LA located?",
             "Where is Barstow located?",
             "Where is Las Vegas located ?"]

for q in questions:
  result = reader.predict(query=q, documents=[doc])
  print(result['answers'])
  print("\n")
# Out:
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.03s/ Batches]
# [<Answer {'answer': 'Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow', 'type': 'extractive', 'score': 0.29487186670303345, 'context': 'Pioneer Boulevard in Los Angeles, making it difficult to get out of the city. However, WBGO was playing some cool jazz, and the weather was cool, making it rather pleasant to be making it out of the city on this Friday afternoon. Nat King Cole was singing as Jo and Maria slowly made their way out of LA and drove toward Barstow', 'offsets_in_document': [{'start': 34, 'end': 362}], 'offsets_in_context': [{'start': 0, 'end': 328}], 'document_id': '60d013212c53db602c9ffc9c2b879225', 'meta': {}}>]
# ...

# %%
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", 
                    use_gpu=True,
                    no_ans_boost=0,
                    return_no_answer=True)

for q in questions:
  result = reader.predict(query=q, documents=[doc])
  print(result)
  print("\n")
# Out:
# INFO - haystack.modeling.utils -  Using devices: CPU
# INFO - haystack.modeling.utils -  Number of GPUs: 0
# INFO - haystack.modeling.model.language_model -  LOADING MODEL
# INFO - haystack.modeling.model.language_model -  =============
# INFO - haystack.modeling.model.language_model -  Could not find deepset/roberta-base-squad2 locally.
# INFO - haystack.modeling.model.language_model -  Looking on Transformers Model Hub (in local cache and online)...
# INFO - haystack.modeling.model.language_model -  Loaded deepset/roberta-base-squad2
# INFO - haystack.modeling.utils -  Using devices: CPU
# INFO - haystack.modeling.utils -  Number of GPUs: 0
# INFO - haystack.modeling.infer -  Got ya 2 parallel workers to do inference ...
# INFO - haystack.modeling.infer -   0     0
# INFO - haystack.modeling.infer -  /w\   /w\
# INFO - haystack.modeling.infer -  /'\   / \
# Inferencing Samples: 100%|██████████| 1/1 [00:01<00:00,  1.05s/ Batches]
# ...
